# %% [markdown]
# # MIS202 Exercise 4 — Notebook State and Execution Order
#
# ## Launch standard (Formative00 Part 4)
# 1) Open **Miniforge Prompt**
# 2) `conda activate wsu_mis_base`
# 3) `jupyter lab`
# 4) In JupyterLab, confirm the kernel is **WSU MIS Base (wsu_mis_base)** (top-right)
#
# This notebook will warn you if you are not in the correct environment.

# %%
import os, sys

print('Python executable:')
print(sys.executable)
print('\nPython version:')
print(sys.version.split()[0])

env = os.environ.get('CONDA_DEFAULT_ENV')
print('\nConda environment:')
print(env)

if env != 'wsu_mis_base':
    print('\n⚠️ WARNING: You are NOT running in conda env wsu_mis_base.')
    print('Fix: Close this notebook, open Miniforge Prompt, run: conda activate wsu_mis_base, then start: jupyter lab')
else:
    print('\n✅ Correct environment detected (wsu_mis_base).')

# %% [markdown]
# # MIS202 – Exercise 4: Python Programming Fundamentals
#
# This notebook demonstrates how a Python program executes in an interpreted environment.
#
# You will:
# - Run each code cell (Shift+Enter)
# - Modify a variable
# - Observe how output changes
# - Capture evidence for your OneNote artifact

# %% [markdown]
# ## Step 1: Basic Output
#
# Run the cell below to see Python produce output.

# %%
print("Welcome to MIS202 Python programming")

# %% [markdown]
# ## Step 2: Variables and Calculation
#
# This cell uses variables to perform a simple calculation.

# %%
hours_worked = 10
hourly_rate = 20

total_pay = hours_worked * hourly_rate

print("Total pay:", total_pay)

# %% [markdown]
# ### Your task
#
# Change the value of `hours_worked` and re-run the cell.
#
# Observe how the output changes.

# %% [markdown]
# ## Step 3: Decision Logic (if / else)
#
# This cell demonstrates how Python makes decisions.

# %%
if total_pay >= 200:
    print("Pay meets minimum target")
else:
    print("Pay does not meet minimum target")

# %% [markdown]
# ### Your task
#
# Modify the earlier values so that the program produces the *other* message.
#
# Re-run the cells in order.

# %% [markdown]
# ## What to Submit
#
# For your MIS202 Assignment Submission Artifact:
#
# - Capture **one screenshot** showing:
#   - A Python code cell
#   - The output below it
# - Paste the screenshot into OneNote
# - Add **one sentence** explaining what the output demonstrates about how the program works
